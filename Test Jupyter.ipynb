# %% [markdown]
# # **Evaluation de commentaires**
# ## Thêmes abordés
# * data correction
# * split train-dev-test
# * embedding
# * one hot encoder
# * LTSM
# * data visualization

# %%
from utils2 import * 
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

assert tf.__version__ >= "2.0"

np.random.seed(0)

# %% [markdown]
# # **Pistes de travail**
#
# * Tester tensorBoard pour visualiser loss/accuracy/other...
# * Automatiser fine-tuning hyperparameters (dichotomie peut-être, keras tuner)

# %%
# Data paths
EMBEDDING_PATH = "./data/glove.6B.50d.txt"
COMMENT_PATH = "./data/tripadvisor_hotel_reviews.csv"

# %%
# Load data
dataset = pd.read_csv(COMMENT_PATH)
dataset.info()
dataset = np.array(dataset)
dataset_of_length = pd.DataFrame([len(comment[0]) for comment in dataset], columns=['Length of sentences'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20491 entries, 0 to 20490
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  20491 non-null  object
#  1   Rating  20491 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 320.3+ KB

# %%
dataset_of_length.hist(bins=100)
plt.show()
print(dataset_of_length.describe())
# Out:
#        Length of sentences
# count         20491.000000
# mean            724.896882
# std             689.101093
# min              44.000000
# 25%             339.000000
# 50%             537.000000
# 75%             859.000000
# max           13501.000000
